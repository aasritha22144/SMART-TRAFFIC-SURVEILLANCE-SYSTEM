# %%
# !pip install opencv-python numpy imutils ultralytics scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\lenovo\appdata\roaming\python\python312\site-packages (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python312\site-packages (2.2.4)
# Requirement already satisfied: imutils in c:\users\lenovo\appdata\roaming\python\python312\site-packages (0.5.4)
# Requirement already satisfied: ultralytics in c:\users\lenovo\appdata\roaming\python\python312\site-packages (8.3.72)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\roaming\python\python312\site-packages (1.5.0)
# Collecting numpy
#   Downloading numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (3.8.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (5.9.7)
# Requirement already satisfied: py-cpuinfo in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (0.13.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: sympy in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.5 MB 882.6 kB/s eta 0:00:17
#    -- ------------------------------------- 1.0/15.5 MB 1.2 MB/s eta 0:00:13
#    --- ------------------------------------ 1.3/15.5 MB 1.3 MB/s eta 0:00:11
#    --- ------------------------------------ 1.3/15.5 MB 1.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 1.6/15.5 MB 1.1 MB/s eta 0:00:14
#    ---- ----------------------------------- 1.6/15.5 MB 1.1 MB/s eta 0:00:14
#    ---- ----------------------------------- 1.8/15.5 MB 923.6 kB/s eta 0:00:15
#    ---- ----------------------------------- 1.8/15.5 MB 923.6 kB/s eta 0:00:15
#    ----- ---------------------------------- 2.1/15.5 MB 876.7 kB/s eta 0:00:16
#    ------ --------------------------------- 2.6/15.5 MB 974.1 kB/s eta 0:00:14
#    ------ --------------------------------- 2.6/15.5 MB 974.1 kB/s eta 0:00:14
#    ------- -------------------------------- 2.9/15.5 MB 958.8 kB/s eta 0:00:14
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.1/15.5 MB 976.5 kB/s eta 0:00:13
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    -------- ------------------------------- 3.4/15.5 MB 684.9 kB/s eta 0:00:18
#    --------- ------------------------------ 3.7/15.5 MB 384.7 kB/s eta 0:00:31
#    --------- ------------------------------ 3.7/15.5 MB 384.7 kB/s eta 0:00:31
#    --------- ------------------------------ 3.7/15.5 MB 384.7 kB/s eta 0:00:31
#    --------- ------------------------------ 3.7/15.5 MB 384.7 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 3.9/15.5 MB 377.0 kB/s eta 0:00:31
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ---------- ----------------------------- 4.2/15.5 MB 347.1 kB/s eta 0:00:33
#    ----------- ---------------------------- 4.5/15.5 MB 329.4 kB/s eta 0:00:34
#    ----------- ---------------------------- 4.5/15.5 MB 329.4 kB/s eta 0:00:34
#    ----------- ---------------------------- 4.5/15.5 MB 329.4 kB/s eta 0:00:34
#    ------------ --------------------------- 4.7/15.5 MB 336.7 kB/s eta 0:00:33
#    ------------ --------------------------- 4.7/15.5 MB 336.7 kB/s eta 0:00:33
#    ------------ --------------------------- 4.7/15.5 MB 336.7 kB/s eta 0:00:33
#    ------------ --------------------------- 5.0/15.5 MB 339.3 kB/s eta 0:00:32
#    ------------ --------------------------- 5.0/15.5 MB 339.3 kB/s eta 0:00:32
#    ------------- -------------------------- 5.2/15.5 MB 348.0 kB/s eta 0:00:30
#    ------------- -------------------------- 5.2/15.5 MB 348.0 kB/s eta 0:00:30
#    ------------- -------------------------- 5.2/15.5 MB 348.0 kB/s eta 0:00:30
#    -------------- ------------------------- 5.5/15.5 MB 350.3 kB/s eta 0:00:29
#    -------------- ------------------------- 5.5/15.5 MB 350.3 kB/s eta 0:00:29
#    -------------- ------------------------- 5.5/15.5 MB 350.3 kB/s eta 0:00:29
#    -------------- ------------------------- 5.8/15.5 MB 352.0 kB/s eta 0:00:28
#    -------------- ------------------------- 5.8/15.5 MB 352.0 kB/s eta 0:00:28
#    -------------- ------------------------- 5.8/15.5 MB 352.0 kB/s eta 0:00:28
#    --------------- ------------------------ 6.0/15.5 MB 354.6 kB/s eta 0:00:27
#    --------------- ------------------------ 6.0/15.5 MB 354.6 kB/s eta 0:00:27
#    ---------------- ----------------------- 6.3/15.5 MB 361.6 kB/s eta 0:00:26
#    ---------------- ----------------------- 6.3/15.5 MB 361.6 kB/s eta 0:00:26
#    ---------------- ----------------------- 6.3/15.5 MB 361.6 kB/s eta 0:00:26
#    ---------------- ----------------------- 6.6/15.5 MB 362.1 kB/s eta 0:00:25
#    ---------------- ----------------------- 6.6/15.5 MB 362.1 kB/s eta 0:00:25
#    ---------------- ----------------------- 6.6/15.5 MB 362.1 kB/s eta 0:00:25
#    ---------------- ----------------------- 6.6/15.5 MB 362.1 kB/s eta 0:00:25
#    ---------------- ----------------------- 6.6/15.5 MB 362.1 kB/s eta 0:00:25
#    ----------------- ---------------------- 6.8/15.5 MB 358.5 kB/s eta 0:00:25
#    ----------------- ---------------------- 6.8/15.5 MB 358.5 kB/s eta 0:00:25
#    ----------------- ---------------------- 6.8/15.5 MB 358.5 kB/s eta 0:00:25
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.1/15.5 MB 360.2 kB/s eta 0:00:24
#    ------------------ --------------------- 7.3/15.5 MB 341.9 kB/s eta 0:00:24
#    ------------------ --------------------- 7.3/15.5 MB 341.9 kB/s eta 0:00:24
#    ------------------ --------------------- 7.3/15.5 MB 341.9 kB/s eta 0:00:24
#    ------------------ --------------------- 7.3/15.5 MB 341.9 kB/s eta 0:00:24
#    ------------------- -------------------- 7.6/15.5 MB 340.2 kB/s eta 0:00:24
#    ------------------- -------------------- 7.6/15.5 MB 340.2 kB/s eta 0:00:24
#    -------------------- ------------------- 7.9/15.5 MB 344.3 kB/s eta 0:00:23
#    -------------------- ------------------- 7.9/15.5 MB 344.3 kB/s eta 0:00:23
#    -------------------- ------------------- 7.9/15.5 MB 344.3 kB/s eta 0:00:23
#    -------------------- ------------------- 8.1/15.5 MB 348.1 kB/s eta 0:00:22
#    -------------------- ------------------- 8.1/15.5 MB 348.1 kB/s eta 0:00:22
#    -------------------- ------------------- 8.1/15.5 MB 348.1 kB/s eta 0:00:22
#    --------------------- ------------------ 8.4/15.5 MB 350.2 kB/s eta 0:00:21
#    --------------------- ------------------ 8.4/15.5 MB 350.2 kB/s eta 0:00:21
#    ---------------------- ----------------- 8.7/15.5 MB 353.7 kB/s eta 0:00:20
#    ---------------------- ----------------- 8.7/15.5 MB 353.7 kB/s eta 0:00:20
#    ---------------------- ----------------- 8.7/15.5 MB 353.7 kB/s eta 0:00:20
#    ---------------------- ----------------- 8.7/15.5 MB 353.7 kB/s eta 0:00:20
#    ---------------------- ----------------- 8.7/15.5 MB 353.7 kB/s eta 0:00:20
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ---------------------- ----------------- 8.9/15.5 MB 349.8 kB/s eta 0:00:19
#    ----------------------- ---------------- 9.2/15.5 MB 341.2 kB/s eta 0:00:19
#    ----------------------- ---------------- 9.2/15.5 MB 341.2 kB/s eta 0:00:19
#    ------------------------ --------------- 9.4/15.5 MB 344.6 kB/s eta 0:00:18
#    ------------------------ --------------- 9.4/15.5 MB 344.6 kB/s eta 0:00:18
#    ------------------------- -------------- 9.7/15.5 MB 347.9 kB/s eta 0:00:17
#    ------------------------- -------------- 9.7/15.5 MB 347.9 kB/s eta 0:00:17
#    ------------------------- -------------- 9.7/15.5 MB 347.9 kB/s eta 0:00:17
#    ------------------------- -------------- 10.0/15.5 MB 349.9 kB/s eta 0:00:16
#    ------------------------- -------------- 10.0/15.5 MB 349.9 kB/s eta 0:00:16
#    -------------------------- ------------- 10.2/15.5 MB 354.2 kB/s eta 0:00:15
#    -------------------------- ------------- 10.2/15.5 MB 354.2 kB/s eta 0:00:15
#    -------------------------- ------------- 10.2/15.5 MB 354.2 kB/s eta 0:00:15
#    --------------------------- ------------ 10.5/15.5 MB 357.0 kB/s eta 0:00:15
#    --------------------------- ------------ 10.5/15.5 MB 357.0 kB/s eta 0:00:15
#    --------------------------- ------------ 10.7/15.5 MB 361.0 kB/s eta 0:00:14
#    --------------------------- ------------ 10.7/15.5 MB 361.0 kB/s eta 0:00:14
#    ---------------------------- ----------- 11.0/15.5 MB 364.5 kB/s eta 0:00:13
#    ----------------------------- ---------- 11.3/15.5 MB 368.9 kB/s eta 0:00:12
#    ----------------------------- ---------- 11.3/15.5 MB 368.9 kB/s eta 0:00:12
#    ----------------------------- ---------- 11.5/15.5 MB 368.2 kB/s eta 0:00:11
#    ----------------------------- ---------- 11.5/15.5 MB 368.2 kB/s eta 0:00:11
#    ------------------------------ --------- 11.8/15.5 MB 350.6 kB/s eta 0:00:11
#    ------------------------------ --------- 11.8/15.5 MB 350.6 kB/s eta 0:00:11
#    ------------------------------ --------- 11.8/15.5 MB 350.6 kB/s eta 0:00:11
#    ------------------------------ --------- 11.8/15.5 MB 350.6 kB/s eta 0:00:11
#    ------------------------------ --------- 11.8/15.5 MB 350.6 kB/s eta 0:00:11
#    ------------------------------- -------- 12.1/15.5 MB 341.9 kB/s eta 0:00:11
#    ------------------------------- -------- 12.1/15.5 MB 341.9 kB/s eta 0:00:11
#    ------------------------------- -------- 12.1/15.5 MB 341.9 kB/s eta 0:00:11
#    ------------------------------- -------- 12.3/15.5 MB 332.6 kB/s eta 0:00:10
#    ------------------------------- -------- 12.3/15.5 MB 332.6 kB/s eta 0:00:10
#    ------------------------------- -------- 12.3/15.5 MB 332.6 kB/s eta 0:00:10
#    ------------------------------- -------- 12.3/15.5 MB 332.6 kB/s eta 0:00:10
#    -------------------------------- ------- 12.6/15.5 MB 320.9 kB/s eta 0:00:10
#    -------------------------------- ------- 12.6/15.5 MB 320.9 kB/s eta 0:00:10
#    --------------------------------- ------ 12.8/15.5 MB 325.8 kB/s eta 0:00:09
#    --------------------------------- ------ 12.8/15.5 MB 325.8 kB/s eta 0:00:09
#    --------------------------------- ------ 13.1/15.5 MB 330.9 kB/s eta 0:00:08
#    --------------------------------- ------ 13.1/15.5 MB 330.9 kB/s eta 0:00:08
#    ---------------------------------- ----- 13.4/15.5 MB 334.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 13.4/15.5 MB 334.7 kB/s eta 0:00:07
#    ---------------------------------- ----- 13.4/15.5 MB 334.7 kB/s eta 0:00:07
#    ----------------------------------- ---- 13.6/15.5 MB 382.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 13.6/15.5 MB 382.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 13.6/15.5 MB 382.2 kB/s eta 0:00:05
#    ----------------------------------- ---- 13.9/15.5 MB 382.9 kB/s eta 0:00:05
#    ----------------------------------- ---- 13.9/15.5 MB 382.9 kB/s eta 0:00:05
#    ------------------------------------ --- 14.2/15.5 MB 385.9 kB/s eta 0:00:04
#    ------------------------------------ --- 14.2/15.5 MB 385.9 kB/s eta 0:00:04
#    ------------------------------------- -- 14.4/15.5 MB 388.2 kB/s eta 0:00:03
#    ------------------------------------- -- 14.4/15.5 MB 388.2 kB/s eta 0:00:03
#    ------------------------------------- -- 14.7/15.5 MB 391.9 kB/s eta 0:00:03
#    -------------------------------------- - 14.9/15.5 MB 398.8 kB/s eta 0:00:02
#    ---------------------------------------- 15.5/15.5 MB 415.0 kB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deepface 0.0.93 requires tensorflow>=1.9.0, which is not installed.
# retina-face 0.0.17 requires tensorflow>=1.9.0, which is not installed.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# facenet-pytorch 2.6.0 requires Pillow<10.3.0,>=10.2.0, but you have pillow 11.1.0 which is incompatible.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 5.29.4 which is incompatible.
# tensorflow-intel 2.17.1 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# tensorflow-intel 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.4 which is incompatible.
# tensorflow-intel 2.17.1 requires tensorboard<2.18,>=2.17, but you have tensorboard 2.19.0 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
import os
import cv2
import shutil
from tqdm import tqdm

# Set dataset path
DATASET_PATH = r"C:\Users\LENOVO\Downloads\archive (3)\Video-Accident-Dataset"
FRAME_OUTPUT_DIR = "extracted_frames"
FRAME_INTERVAL = 30  # Grab one frame every 30 frames (adjust based on your need)

# Reset frame output directory
if os.path.exists(FRAME_OUTPUT_DIR):
    shutil.rmtree(FRAME_OUTPUT_DIR)
os.makedirs(FRAME_OUTPUT_DIR)

# Frame extraction function
def extract_frames_from_videos(dataset_path, output_dir, frame_interval=FRAME_INTERVAL):
    classes = [c for c in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, c))]
    class_to_label = {cls: idx for idx, cls in enumerate(classes)}

    for cls in tqdm(classes, desc="Extracting frames"):
        class_path = os.path.join(dataset_path, cls)
        output_class_path = os.path.join(output_dir, cls)
        os.makedirs(output_class_path, exist_ok=True)

        for video_name in os.listdir(class_path):
            video_path = os.path.join(class_path, video_name)

            if not video_name.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
                print(f"[SKIPPED] {video_name} is not a supported video format.")
                continue

            cap = cv2.VideoCapture(video_path)
            if not cap.isOpened():
                print(f"[ERROR] Cannot open video: {video_path}")
                continue

            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            saved_frame_id = 0
            frame_id = 0
            success = True

            while success and frame_id < total_frames:
                success = cap.grab()
                if frame_id % frame_interval == 0 and success:
                    ret, frame = cap.retrieve()
                    if ret:
                        frame_filename = f"{video_name[:-4]}_frame{saved_frame_id}.jpg"
                        frame_path = os.path.join(output_class_path, frame_filename)
                        try:
                            cv2.imwrite(frame_path, frame)
                        except Exception as e:
                            print(f"[ERROR] Failed to write frame: {e}")
                        saved_frame_id += 1
                frame_id += 1

            cap.release()
            cv2.destroyAllWindows()
            print(f"[INFO] Extracted {saved_frame_id} frames from {video_name}")

    return class_to_label

# Run extraction
class_labels = extract_frames_from_videos(DATASET_PATH, FRAME_OUTPUT_DIR)
print("✅ Frame Extraction Done.")
print("Class to Label Mapping:", class_labels)
# Out:
# Extracting frames:   0%|          | 0/12 [00:00<?, ?it/s]
# [INFO] Extracted 6 frames from collision_with_motorcycle_1.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_10.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_100.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_101.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_102.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_103.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_104.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_105.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_106.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_107.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_108.mp4
# [INFO] Extracted 12 frames from collision_with_motorcycle_109.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_11.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_110.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_111.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_112.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_113.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_114.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_115.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_116.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_117.mp4
# [INFO] Extracted 3 frames from collision_with_motorcycle_118.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_119.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_12.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_120.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_121.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_122.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_123.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_124.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_125.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_126.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_127.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_128.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_129.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_13.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_130.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_131.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_132.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_133.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_134.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_135.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_136.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_137.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_138.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_139.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_14.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_140.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_141.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_142.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_143.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_144.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_145.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_146.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_147.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_148.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_149.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_15.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_150.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_151.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_152.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_153.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_154.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_155.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_156.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_157.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_158.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_159.mp4
# [INFO] Extracted 3 frames from collision_with_motorcycle_16.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_160.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_161.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_162.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_163.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_164.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_165.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_166.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_17.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_18.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_19.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_2.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_20.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_21.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_22.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_23.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_24.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_25.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_26.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_27.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_28.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_29.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_3.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_30.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_31.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_32.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_33.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_34.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_35.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_36.mp4
# [INFO] Extracted 9 frames from collision_with_motorcycle_37.mp4
# [INFO] Extracted 9 frames from collision_with_motorcycle_38.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_39.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_4.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_40.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_41.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_42.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_43.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_44.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_45.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_46.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_47.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_48.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_49.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_5.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_50.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_51.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_52.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_53.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_54.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_55.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_56.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_57.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_58.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_59.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_6.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_60.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_61.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_62.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_63.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_64.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_65.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_66.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_67.mp4
# [INFO] Extracted 3 frames from collision_with_motorcycle_68.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_69.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_7.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_70.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_71.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_72.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_73.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_74.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_75.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_76.mp4
# [INFO] Extracted 4 frames from collision_with_motorcycle_77.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_78.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_79.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_8.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_80.mp4
# [INFO] Extracted 8 frames from collision_with_motorcycle_81.mp4
# [INFO] Extracted 10 frames from collision_with_motorcycle_82.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_83.mp4
# [INFO] Extracted 3 frames from collision_with_motorcycle_84.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_85.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_86.mp4
# [INFO] Extracted 7 frames from collision_with_motorcycle_87.mp4
# [INFO] Extracted 10 frames from collision_with_motorcycle_88.mp4
# [INFO] Extracted 10 frames from collision_with_motorcycle_89.mp4
# [INFO] Extracted 11 frames from collision_with_motorcycle_9.mp4
# [INFO] Extracted 10 frames from collision_with_motorcycle_90.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_91.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_92.mp4
# [INFO] Extracted 6 frames from collision_with_motorcycle_93.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_94.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_95.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_96.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_97.mp4
# [INFO] Extracted 5 frames from collision_with_motorcycle_98.mp4
# Extracting frames:   8%|▊         | 1/12 [00:44<08:04, 44.05s/it]
# [INFO] Extracted 5 frames from collision_with_motorcycle_99.mp4
# [INFO] Extracted 2 frames from collision_with_stationary_object_1.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_10.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_100.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_101.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_102.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_103.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_104.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_105.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_106.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_107.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_108.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_109.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_11.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_110.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_111.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_112.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_113.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_114.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_115.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_116.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_117.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_118.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_119.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_12.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_120.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_121.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_122.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_123.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_124.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_125.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_126.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_127.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_128.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_129.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_13.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_130.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_131.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_132.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_133.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_134.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_135.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_136.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_137.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_138.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_139.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_14.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_140.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_141.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_142.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_143.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_144.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_145.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_146.mp4
# [INFO] Extracted 2 frames from collision_with_stationary_object_147.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_148.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_149.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_15.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_150.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_151.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_152.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_153.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_154.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_155.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_156.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_157.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_158.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_159.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_16.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_160.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_161.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_162.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_163.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_164.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_165.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_166.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_167.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_168.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_169.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_17.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_170.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_171.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_172.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_173.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_174.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_175.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_176.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_177.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_178.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_179.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_18.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_180.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_181.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_182.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_183.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_184.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_185.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_186.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_187.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_188.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_189.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_19.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_190.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_191.mp4
# [INFO] Extracted 15 frames from collision_with_stationary_object_192.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_193.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_194.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_195.mp4
# [INFO] Extracted 12 frames from collision_with_stationary_object_196.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_197.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_198.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_199.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_2.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_20.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_200.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_201.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_202.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_203.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_204.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_205.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_206.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_207.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_208.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_209.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_21.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_210.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_211.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_212.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_213.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_214.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_215.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_216.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_217.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_218.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_219.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_22.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_220.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_221.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_222.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_223.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_224.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_225.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_226.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_227.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_228.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_229.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_23.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_230.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_231.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_232.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_233.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_234.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_235.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_236.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_237.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_238.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_239.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_24.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_240.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_241.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_242.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_243.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_244.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_245.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_246.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_247.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_248.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_249.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_25.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_250.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_251.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_252.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_253.mp4
# [INFO] Extracted 9 frames from collision_with_stationary_object_254.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_255.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_256.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_257.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_258.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_259.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_26.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_260.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_261.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_262.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_263.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_264.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_265.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_266.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_267.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_268.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_269.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_27.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_270.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_271.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_28.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_29.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_3.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_30.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_31.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_32.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_33.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_34.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_35.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_36.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_37.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_38.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_39.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_4.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_40.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_41.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_42.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_43.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_44.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_45.mp4
# [INFO] Extracted 9 frames from collision_with_stationary_object_46.mp4
# [INFO] Extracted 10 frames from collision_with_stationary_object_47.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_48.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_49.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_5.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_50.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_51.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_52.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_53.mp4
# [INFO] Extracted 11 frames from collision_with_stationary_object_54.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_55.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_56.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_57.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_58.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_59.mp4
# [INFO] Extracted 9 frames from collision_with_stationary_object_6.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_60.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_61.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_62.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_63.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_64.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_65.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_66.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_67.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_68.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_69.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_7.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_70.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_71.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_72.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_73.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_74.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_75.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_76.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_77.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_78.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_79.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_8.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_80.mp4
# [INFO] Extracted 8 frames from collision_with_stationary_object_81.mp4
# [INFO] Extracted 9 frames from collision_with_stationary_object_82.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_83.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_84.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_85.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_86.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_87.mp4
# [INFO] Extracted 7 frames from collision_with_stationary_object_88.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_89.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_9.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_90.mp4
# [INFO] Extracted 4 frames from collision_with_stationary_object_91.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_92.mp4
# [INFO] Extracted 2 frames from collision_with_stationary_object_93.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_94.mp4
# [INFO] Extracted 3 frames from collision_with_stationary_object_95.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_96.mp4
# [INFO] Extracted 5 frames from collision_with_stationary_object_97.mp4
# [INFO] Extracted 6 frames from collision_with_stationary_object_98.mp4
# Extracting frames:  17%|█▋        | 2/12 [01:54<09:56, 59.64s/it]
# [INFO] Extracted 6 frames from collision_with_stationary_object_99.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_1.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_10.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_100.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_101.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_102.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_103.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_104.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_105.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_106.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_107.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_108.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_109.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_11.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_110.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_111.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_112.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_113.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_114.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_115.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_116.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_117.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_118.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_119.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_12.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_120.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_121.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_122.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_123.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_124.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_125.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_126.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_127.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_128.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_129.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_13.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_130.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_131.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_132.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_133.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_134.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_135.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_136.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_137.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_138.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_139.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_14.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_140.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_141.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_142.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_143.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_144.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_145.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_146.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_147.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_148.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_149.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_15.mp4
# [INFO] Extracted 11 frames from drifting_or_skidding_150.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_151.mp4
# [INFO] Extracted 17 frames from drifting_or_skidding_152.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_153.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_154.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_155.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_156.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_157.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_158.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_159.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_16.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_160.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_161.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_162.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_163.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_164.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_165.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_166.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_167.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_168.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_169.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_17.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_170.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_171.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_172.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_173.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_174.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_175.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_176.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_177.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_178.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_179.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_18.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_180.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_181.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_182.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_183.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_184.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_185.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_186.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_187.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_188.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_189.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_19.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_190.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_191.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_192.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_193.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_194.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_195.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_196.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_197.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_198.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_199.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_2.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_20.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_200.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_201.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_202.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_203.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_204.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_205.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_206.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_207.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_208.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_209.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_21.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_210.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_211.mp4
# [INFO] Extracted 11 frames from drifting_or_skidding_212.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_213.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_214.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_215.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_216.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_217.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_218.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_219.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_22.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_220.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_221.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_222.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_223.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_224.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_225.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_226.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_227.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_228.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_229.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_23.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_230.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_231.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_232.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_233.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_234.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_235.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_236.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_237.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_238.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_239.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_24.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_240.mp4
# [INFO] Extracted 11 frames from drifting_or_skidding_241.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_242.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_243.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_244.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_245.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_246.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_247.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_248.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_249.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_25.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_250.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_251.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_252.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_253.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_254.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_255.mp4
# [INFO] Extracted 10 frames from drifting_or_skidding_256.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_257.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_258.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_259.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_26.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_260.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_261.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_262.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_263.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_264.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_265.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_266.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_267.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_268.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_269.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_27.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_270.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_271.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_272.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_273.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_274.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_275.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_276.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_277.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_278.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_279.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_28.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_280.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_281.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_282.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_283.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_284.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_285.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_286.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_287.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_288.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_289.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_29.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_290.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_291.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_292.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_293.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_294.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_295.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_296.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_297.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_298.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_299.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_3.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_30.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_300.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_301.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_302.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_303.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_304.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_305.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_306.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_307.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_308.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_309.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_31.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_310.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_311.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_312.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_32.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_33.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_34.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_35.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_36.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_37.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_38.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_39.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_4.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_40.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_41.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_42.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_43.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_44.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_45.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_46.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_47.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_48.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_49.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_5.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_50.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_51.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_52.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_53.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_54.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_55.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_56.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_57.mp4
# [INFO] Extracted 8 frames from drifting_or_skidding_58.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_59.mp4
# [INFO] Extracted 11 frames from drifting_or_skidding_6.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_60.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_61.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_62.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_63.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_64.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_65.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_66.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_67.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_68.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_69.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_7.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_70.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_71.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_72.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_73.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_74.mp4
# [INFO] Extracted 9 frames from drifting_or_skidding_75.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_76.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_77.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_78.mp4
# [INFO] Extracted 6 frames from drifting_or_skidding_79.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_8.mp4
# [INFO] Extracted 4 frames from drifting_or_skidding_80.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_81.mp4
# [INFO] Extracted 3 frames from drifting_or_skidding_82.mp4
# [INFO] Extracted 5 frames from drifting_or_skidding_83.mp4
# [INFO] Extracted 7 frames from drifting_or_skidding_84.mp4
# ...
# [INFO] Extracted 4 frames from rollover_231.mp4
# [INFO] Extracted 4 frames from rollover_232.mp4
# [INFO] Extracted 4 frames from rollover_233.mp4
# [INFO] Extracted 4 frames from rollover_234.mp4
# [INFO] Extracted 5 frames from rollover_235.mp4
# [INFO] Extracted 5 frames from rollover_236.mp4
# [INFO] Extracted 5 frames from rollover_237.mp4
# [INFO] Extracted 9 frames from rollover_238.mp4
# [INFO] Extracted 7 frames from rollover_24.mp4
# [INFO] Extracted 5 frames from rollover_25.mp4
# [INFO] Extracted 5 frames from rollover_26.mp4
# [INFO] Extracted 4 frames from rollover_27.mp4
# [INFO] Extracted 5 frames from rollover_28.mp4
# [INFO] Extracted 4 frames from rollover_29.mp4
# [INFO] Extracted 6 frames from rollover_3.mp4
# [INFO] Extracted 6 frames from rollover_30.mp4
# [INFO] Extracted 5 frames from rollover_31.mp4
# [INFO] Extracted 7 frames from rollover_32.mp4
# [INFO] Extracted 6 frames from rollover_33.mp4
# [INFO] Extracted 6 frames from rollover_34.mp4
# [INFO] Extracted 6 frames from rollover_35.mp4
# [INFO] Extracted 6 frames from rollover_36.mp4
# [INFO] Extracted 4 frames from rollover_37.mp4
# [INFO] Extracted 6 frames from rollover_38.mp4
# [INFO] Extracted 8 frames from rollover_39.mp4
# [INFO] Extracted 5 frames from rollover_4.mp4
# [INFO] Extracted 7 frames from rollover_40.mp4
# [INFO] Extracted 4 frames from rollover_41.mp4
# [INFO] Extracted 6 frames from rollover_42.mp4
# [INFO] Extracted 4 frames from rollover_43.mp4
# [INFO] Extracted 6 frames from rollover_44.mp4
# [INFO] Extracted 64 frames from rollover_45.mp4
# [INFO] Extracted 9 frames from rollover_46.mp4
# [INFO] Extracted 8 frames from rollover_47.mp4
# [INFO] Extracted 3 frames from rollover_48.mp4
# [INFO] Extracted 2 frames from rollover_49.mp4
# [INFO] Extracted 5 frames from rollover_5.mp4
# [INFO] Extracted 8 frames from rollover_50.mp4
# [INFO] Extracted 11 frames from rollover_51.mp4
# [INFO] Extracted 5 frames from rollover_52.mp4
# [INFO] Extracted 5 frames from rollover_53.mp4
# [INFO] Extracted 6 frames from rollover_54.mp4
# [INFO] Extracted 6 frames from rollover_55.mp4
# [INFO] Extracted 7 frames from rollover_56.mp4
# [INFO] Extracted 5 frames from rollover_57.mp4
# [INFO] Extracted 7 frames from rollover_58.mp4
# [INFO] Extracted 4 frames from rollover_59.mp4
# [INFO] Extracted 5 frames from rollover_6.mp4
# [INFO] Extracted 6 frames from rollover_60.mp4
# [INFO] Extracted 8 frames from rollover_61.mp4
# [INFO] Extracted 9 frames from rollover_62.mp4
# [INFO] Extracted 4 frames from rollover_63.mp4
# [INFO] Extracted 4 frames from rollover_64.mp4
# [INFO] Extracted 7 frames from rollover_65.mp4
# [INFO] Extracted 3 frames from rollover_66.mp4
# [INFO] Extracted 8 frames from rollover_67.mp4
# [INFO] Extracted 6 frames from rollover_68.mp4
# [INFO] Extracted 6 frames from rollover_69.mp4
# [INFO] Extracted 5 frames from rollover_7.mp4
# [INFO] Extracted 6 frames from rollover_70.mp4
# [INFO] Extracted 8 frames from rollover_71.mp4
# [INFO] Extracted 7 frames from rollover_72.mp4
# [INFO] Extracted 5 frames from rollover_73.mp4
# [INFO] Extracted 6 frames from rollover_74.mp4
# [INFO] Extracted 3 frames from rollover_75.mp4
# [INFO] Extracted 6 frames from rollover_76.mp4
# [INFO] Extracted 4 frames from rollover_77.mp4
# [INFO] Extracted 5 frames from rollover_78.mp4
# [INFO] Extracted 6 frames from rollover_79.mp4
# [INFO] Extracted 4 frames from rollover_8.mp4
# [INFO] Extracted 6 frames from rollover_80.mp4
# [INFO] Extracted 5 frames from rollover_81.mp4
# [INFO] Extracted 9 frames from rollover_82.mp4
# [INFO] Extracted 5 frames from rollover_83.mp4
# [INFO] Extracted 5 frames from rollover_84.mp4
# [INFO] Extracted 4 frames from rollover_85.mp4
# [INFO] Extracted 5 frames from rollover_86.mp4
# [INFO] Extracted 5 frames from rollover_87.mp4
# [INFO] Extracted 6 frames from rollover_88.mp4
# [INFO] Extracted 5 frames from rollover_89.mp4
# [INFO] Extracted 7 frames from rollover_9.mp4
# [INFO] Extracted 6 frames from rollover_90.mp4
# [INFO] Extracted 5 frames from rollover_91.mp4
# [INFO] Extracted 7 frames from rollover_92.mp4
# [INFO] Extracted 4 frames from rollover_93.mp4
# [INFO] Extracted 7 frames from rollover_94.mp4
# [INFO] Extracted 7 frames from rollover_95.mp4
# [INFO] Extracted 5 frames from rollover_96.mp4
# [INFO] Extracted 6 frames from rollover_97.mp4
# [INFO] Extracted 3 frames from rollover_98.mp4
# Extracting frames:  92%|█████████▏| 11/12 [15:49<01:06, 66.43s/it]
# [INFO] Extracted 5 frames from rollover_99.mp4
# [INFO] Extracted 6 frames from side_collision_1.mp4
# [INFO] Extracted 6 frames from side_collision_10.mp4
# [INFO] Extracted 7 frames from side_collision_100.mp4
# [INFO] Extracted 6 frames from side_collision_101.mp4
# [INFO] Extracted 6 frames from side_collision_102.mp4
# [INFO] Extracted 6 frames from side_collision_103.mp4
# [INFO] Extracted 6 frames from side_collision_104.mp4
# [INFO] Extracted 7 frames from side_collision_105.mp4
# [INFO] Extracted 7 frames from side_collision_106.mp4
# [INFO] Extracted 7 frames from side_collision_107.mp4
# [INFO] Extracted 3 frames from side_collision_108.mp4
# [INFO] Extracted 8 frames from side_collision_109.mp4
# [INFO] Extracted 4 frames from side_collision_11.mp4
# [INFO] Extracted 8 frames from side_collision_110.mp4
# [INFO] Extracted 8 frames from side_collision_111.mp4
# [INFO] Extracted 8 frames from side_collision_112.mp4
# [INFO] Extracted 7 frames from side_collision_113.mp4
# [INFO] Extracted 7 frames from side_collision_114.mp4
# [INFO] Extracted 7 frames from side_collision_115.mp4
# [INFO] Extracted 8 frames from side_collision_116.mp4
# [INFO] Extracted 8 frames from side_collision_117.mp4
# [INFO] Extracted 8 frames from side_collision_118.mp4
# [INFO] Extracted 10 frames from side_collision_119.mp4
# [INFO] Extracted 4 frames from side_collision_12.mp4
# [INFO] Extracted 8 frames from side_collision_120.mp4
# [INFO] Extracted 8 frames from side_collision_121.mp4
# [INFO] Extracted 8 frames from side_collision_122.mp4
# [INFO] Extracted 8 frames from side_collision_123.mp4
# [INFO] Extracted 8 frames from side_collision_124.mp4
# [INFO] Extracted 7 frames from side_collision_125.mp4
# [INFO] Extracted 7 frames from side_collision_126.mp4
# [INFO] Extracted 7 frames from side_collision_127.mp4
# [INFO] Extracted 7 frames from side_collision_128.mp4
# [INFO] Extracted 6 frames from side_collision_129.mp4
# [INFO] Extracted 5 frames from side_collision_13.mp4
# [INFO] Extracted 7 frames from side_collision_130.mp4
# [INFO] Extracted 7 frames from side_collision_131.mp4
# [INFO] Extracted 7 frames from side_collision_132.mp4
# [INFO] Extracted 9 frames from side_collision_133.mp4
# [INFO] Extracted 5 frames from side_collision_134.mp4
# [INFO] Extracted 7 frames from side_collision_135.mp4
# [INFO] Extracted 5 frames from side_collision_136.mp4
# [INFO] Extracted 5 frames from side_collision_137.mp4
# [INFO] Extracted 7 frames from side_collision_138.mp4
# [INFO] Extracted 5 frames from side_collision_139.mp4
# [INFO] Extracted 4 frames from side_collision_14.mp4
# [INFO] Extracted 10 frames from side_collision_140.mp4
# [INFO] Extracted 6 frames from side_collision_141.mp4
# [INFO] Extracted 12 frames from side_collision_142.mp4
# [INFO] Extracted 6 frames from side_collision_143.mp4
# [INFO] Extracted 8 frames from side_collision_144.mp4
# [INFO] Extracted 5 frames from side_collision_145.mp4
# [INFO] Extracted 5 frames from side_collision_146.mp4
# [INFO] Extracted 5 frames from side_collision_147.mp4
# [INFO] Extracted 7 frames from side_collision_148.mp4
# [INFO] Extracted 7 frames from side_collision_149.mp4
# [INFO] Extracted 6 frames from side_collision_15.mp4
# [INFO] Extracted 7 frames from side_collision_150.mp4
# [INFO] Extracted 7 frames from side_collision_151.mp4
# [INFO] Extracted 6 frames from side_collision_152.mp4
# [INFO] Extracted 8 frames from side_collision_153.mp4
# [INFO] Extracted 8 frames from side_collision_154.mp4
# [INFO] Extracted 8 frames from side_collision_155.mp4
# [INFO] Extracted 8 frames from side_collision_156.mp4
# [INFO] Extracted 5 frames from side_collision_157.mp4
# [INFO] Extracted 8 frames from side_collision_158.mp4
# [INFO] Extracted 8 frames from side_collision_159.mp4
# [INFO] Extracted 5 frames from side_collision_16.mp4
# [INFO] Extracted 8 frames from side_collision_160.mp4
# [INFO] Extracted 13 frames from side_collision_161.mp4
# [INFO] Extracted 6 frames from side_collision_162.mp4
# [INFO] Extracted 6 frames from side_collision_163.mp4
# [INFO] Extracted 6 frames from side_collision_164.mp4
# [INFO] Extracted 6 frames from side_collision_165.mp4
# [INFO] Extracted 6 frames from side_collision_166.mp4
# [INFO] Extracted 6 frames from side_collision_167.mp4
# [INFO] Extracted 6 frames from side_collision_168.mp4
# [INFO] Extracted 9 frames from side_collision_169.mp4
# [INFO] Extracted 5 frames from side_collision_17.mp4
# [INFO] Extracted 5 frames from side_collision_170.mp4
# [INFO] Extracted 7 frames from side_collision_171.mp4
# [INFO] Extracted 5 frames from side_collision_172.mp4
# [INFO] Extracted 7 frames from side_collision_173.mp4
# [INFO] Extracted 6 frames from side_collision_174.mp4
# [INFO] Extracted 6 frames from side_collision_175.mp4
# [INFO] Extracted 5 frames from side_collision_176.mp4
# [INFO] Extracted 5 frames from side_collision_177.mp4
# [INFO] Extracted 8 frames from side_collision_178.mp4
# [INFO] Extracted 4 frames from side_collision_179.mp4
# [INFO] Extracted 8 frames from side_collision_18.mp4
# [INFO] Extracted 4 frames from side_collision_180.mp4
# [INFO] Extracted 4 frames from side_collision_181.mp4
# [INFO] Extracted 6 frames from side_collision_182.mp4
# [INFO] Extracted 6 frames from side_collision_183.mp4
# [INFO] Extracted 6 frames from side_collision_184.mp4
# [INFO] Extracted 9 frames from side_collision_185.mp4
# [INFO] Extracted 5 frames from side_collision_186.mp4
# [INFO] Extracted 7 frames from side_collision_187.mp4
# [INFO] Extracted 5 frames from side_collision_188.mp4
# [INFO] Extracted 4 frames from side_collision_189.mp4
# [INFO] Extracted 6 frames from side_collision_19.mp4
# [INFO] Extracted 4 frames from side_collision_190.mp4
# [INFO] Extracted 6 frames from side_collision_191.mp4
# [INFO] Extracted 6 frames from side_collision_192.mp4
# [INFO] Extracted 6 frames from side_collision_193.mp4
# [INFO] Extracted 4 frames from side_collision_194.mp4
# [INFO] Extracted 4 frames from side_collision_195.mp4
# [INFO] Extracted 4 frames from side_collision_196.mp4
# [INFO] Extracted 5 frames from side_collision_197.mp4
# [INFO] Extracted 5 frames from side_collision_198.mp4
# [INFO] Extracted 5 frames from side_collision_199.mp4
# [INFO] Extracted 6 frames from side_collision_2.mp4
# [INFO] Extracted 5 frames from side_collision_20.mp4
# [INFO] Extracted 5 frames from side_collision_200.mp4
# [INFO] Extracted 5 frames from side_collision_201.mp4
# [INFO] Extracted 5 frames from side_collision_202.mp4
# [INFO] Extracted 5 frames from side_collision_203.mp4
# [INFO] Extracted 6 frames from side_collision_204.mp4
# [INFO] Extracted 6 frames from side_collision_205.mp4
# [INFO] Extracted 4 frames from side_collision_206.mp4
# [INFO] Extracted 5 frames from side_collision_207.mp4
# [INFO] Extracted 5 frames from side_collision_208.mp4
# [INFO] Extracted 10 frames from side_collision_209.mp4
# [INFO] Extracted 5 frames from side_collision_21.mp4
# [INFO] Extracted 3 frames from side_collision_210.mp4
# [INFO] Extracted 4 frames from side_collision_22.mp4
# [INFO] Extracted 4 frames from side_collision_23.mp4
# [INFO] Extracted 5 frames from side_collision_24.mp4
# [INFO] Extracted 4 frames from side_collision_25.mp4
# [INFO] Extracted 7 frames from side_collision_26.mp4
# [INFO] Extracted 6 frames from side_collision_27.mp4
# [INFO] Extracted 5 frames from side_collision_28.mp4
# [INFO] Extracted 4 frames from side_collision_29.mp4
# [INFO] Extracted 6 frames from side_collision_3.mp4
# [INFO] Extracted 5 frames from side_collision_30.mp4
# [INFO] Extracted 6 frames from side_collision_31.mp4
# [INFO] Extracted 5 frames from side_collision_32.mp4
# [INFO] Extracted 6 frames from side_collision_33.mp4
# [INFO] Extracted 6 frames from side_collision_34.mp4
# [INFO] Extracted 6 frames from side_collision_35.mp4
# [INFO] Extracted 9 frames from side_collision_36.mp4
# [INFO] Extracted 5 frames from side_collision_37.mp4
# [INFO] Extracted 9 frames from side_collision_38.mp4
# [INFO] Extracted 5 frames from side_collision_39.mp4
# [INFO] Extracted 4 frames from side_collision_4.mp4
# [INFO] Extracted 9 frames from side_collision_40.mp4
# [INFO] Extracted 9 frames from side_collision_41.mp4
# [INFO] Extracted 9 frames from side_collision_42.mp4
# [INFO] Extracted 9 frames from side_collision_43.mp4
# [INFO] Extracted 9 frames from side_collision_44.mp4
# [INFO] Extracted 7 frames from side_collision_45.mp4
# [INFO] Extracted 6 frames from side_collision_46.mp4
# [INFO] Extracted 6 frames from side_collision_47.mp4
# [INFO] Extracted 7 frames from side_collision_48.mp4
# [INFO] Extracted 6 frames from side_collision_49.mp4
# [INFO] Extracted 4 frames from side_collision_5.mp4
# [INFO] Extracted 7 frames from side_collision_50.mp4
# [INFO] Extracted 6 frames from side_collision_51.mp4
# [INFO] Extracted 6 frames from side_collision_52.mp4
# [INFO] Extracted 6 frames from side_collision_53.mp4
# [INFO] Extracted 6 frames from side_collision_54.mp4
# [INFO] Extracted 8 frames from side_collision_55.mp4
# [INFO] Extracted 8 frames from side_collision_56.mp4
# [INFO] Extracted 8 frames from side_collision_57.mp4
# [INFO] Extracted 8 frames from side_collision_58.mp4
# [INFO] Extracted 5 frames from side_collision_59.mp4
# [INFO] Extracted 8 frames from side_collision_6.mp4
# [INFO] Extracted 7 frames from side_collision_60.mp4
# [INFO] Extracted 7 frames from side_collision_61.mp4
# [INFO] Extracted 7 frames from side_collision_62.mp4
# [INFO] Extracted 5 frames from side_collision_63.mp4
# [INFO] Extracted 7 frames from side_collision_64.mp4
# [INFO] Extracted 7 frames from side_collision_65.mp4
# [INFO] Extracted 5 frames from side_collision_66.mp4
# [INFO] Extracted 5 frames from side_collision_67.mp4
# [INFO] Extracted 5 frames from side_collision_68.mp4
# [INFO] Extracted 6 frames from side_collision_69.mp4
# [INFO] Extracted 8 frames from side_collision_7.mp4
# [INFO] Extracted 6 frames from side_collision_70.mp4
# [INFO] Extracted 6 frames from side_collision_71.mp4
# [INFO] Extracted 6 frames from side_collision_72.mp4
# [INFO] Extracted 6 frames from side_collision_73.mp4
# [INFO] Extracted 6 frames from side_collision_74.mp4
# [INFO] Extracted 9 frames from side_collision_75.mp4
# [INFO] Extracted 8 frames from side_collision_76.mp4
# [INFO] Extracted 8 frames from side_collision_77.mp4
# [INFO] Extracted 9 frames from side_collision_78.mp4
# [INFO] Extracted 3 frames from side_collision_79.mp4
# [INFO] Extracted 5 frames from side_collision_8.mp4
# [INFO] Extracted 5 frames from side_collision_80.mp4
# [INFO] Extracted 4 frames from side_collision_81.mp4
# [INFO] Extracted 3 frames from side_collision_82.mp4
# [INFO] Extracted 5 frames from side_collision_83.mp4
# [INFO] Extracted 5 frames from side_collision_84.mp4
# [INFO] Extracted 5 frames from side_collision_85.mp4
# [INFO] Extracted 4 frames from side_collision_86.mp4
# [INFO] Extracted 3 frames from side_collision_87.mp4
# [INFO] Extracted 3 frames from side_collision_88.mp4
# [INFO] Extracted 4 frames from side_collision_89.mp4
# [INFO] Extracted 4 frames from side_collision_9.mp4
# [INFO] Extracted 4 frames from side_collision_90.mp4
# [INFO] Extracted 3 frames from side_collision_91.mp4
# [INFO] Extracted 4 frames from side_collision_92.mp4
# [INFO] Extracted 5 frames from side_collision_93.mp4
# [INFO] Extracted 5 frames from side_collision_94.mp4
# [INFO] Extracted 7 frames from side_collision_95.mp4
# [INFO] Extracted 6 frames from side_collision_96.mp4
# [INFO] Extracted 6 frames from side_collision_97.mp4
# [INFO] Extracted 8 frames from side_collision_98.mp4
# Extracting frames: 100%|██████████| 12/12 [16:52<00:00, 84.37s/it]
# [INFO] Extracted 7 frames from side_collision_99.mp4
# ✅ Frame Extraction Done.
# Class to Label Mapping: {'collision_with_motorcycle': 0, 'collision_with_stationary_object': 1, 'drifting_or_skidding': 2, 'fire_or_explosions': 3, 'head_on_collision': 4, 'negative_samples': 5, 'objects_falling': 6, 'other_crash': 7, 'pedestrian_hit': 8, 'rear_collision': 9, 'rollover': 10, 'side_collision': 11}

# %%
import cv2
import numpy as np
import supervision as sv
from ultralytics import YOLO

# Load YOLOv8 model
vehicle_model = YOLO("yolov8n.pt")

# COCO vehicle classes: car, motorcycle, bus, truck
vehicle_labels = [2, 3, 5, 7]

# Create a box annotator with only the supported argument 'thickness'
box_annotator = sv.BoxAnnotator(thickness=2)

def detect_and_track_vehicles_visual(video_path):
    print(f"🔍 Loading video from: {video_path}")
    
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"[ERROR] Cannot open video: {video_path}")
        return

    tracker = sv.ByteTrack()
    frame_count = 0
    max_frames = 200

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret or frame_count >= max_frames:
            break

        result = vehicle_model(frame, verbose=False)[0]
        detections = sv.Detections.from_ultralytics(result)

        # Filter to vehicle classes
        vehicle_detections = detections[np.isin(detections.class_id, vehicle_labels)]

        # Track objects
        tracked_detections = tracker.update_with_detections(vehicle_detections)

        # Annotate bounding boxes
        annotated_frame = box_annotator.annotate(
            scene=frame.copy(),
            detections=tracked_detections
        )

        # Add tracker IDs manually using OpenCV putText
        for bbox, track_id in zip(tracked_detections.xyxy, tracked_detections.tracker_id):
            x1, y1, x2, y2 = map(int, bbox)
            cv2.putText(annotated_frame, f"ID {track_id}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)

        # Show frame
        cv2.imshow("Vehicle Detection & Tracking", annotated_frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

        frame_count += 1

    cap.release()
    cv2.destroyAllWindows()
    print("🎥 Display finished.")

# ==== RUN THE FUNCTION ====
video_path = r"C:\Users\LENOVO\Downloads\128506-741503593_tiny.mp4"
detect_and_track_vehicles_visual(video_path)
# Out:
# 🔍 Loading video from: C:\Users\LENOVO\Downloads\128506-741503593_tiny.mp4
# 🎥 Display finished.

# %%
# !pip install torch torchvision scikit-learn
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report
import numpy as np

# === Config ===
DATA_DIR = "extracted_frames"
BATCH_SIZE = 32
IMG_SIZE = 224
EPOCHS = 5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Data Loaders ===
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(DATA_DIR, transform=transform)
class_names = train_dataset.classes
num_classes = len(class_names)

# Train/Validation Split
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_set, val_set = torch.utils.data.random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)

# === Model ===
model = models.mobilenet_v2(pretrained=True)
model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
model = model.to(DEVICE)

# === Loss & Optimizer ===
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# === Training Loop ===
for epoch in range(EPOCHS):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(DEVICE), labels.to(DEVICE)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_accuracy = 100 * correct / total
    print(f"Epoch {epoch+1}/{EPOCHS}, Loss: {running_loss:.4f}, Accuracy: {train_accuracy:.2f}%")

# === Evaluation ===
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(DEVICE)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=class_names))

# === Save Model ===
torch.save(model.state_dict(), "incident_classifier_pytorch.pth")
print("✅ Model saved as incident_classifier_pytorch.pth")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\lenovo\appdata\roaming\python\python312\site-packages (2.2.2)
# Requirement already satisfied: torchvision in c:\users\lenovo\appdata\roaming\python\python312\site-packages (0.17.2)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\roaming\python\python312\site-packages (1.5.0)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (4.13.1)
# Requirement already satisfied: sympy in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\appdata\roaming\python\python312\site-packages (from sympy->torch) (1.3.0)
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\LENOVO\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to C:\Users\LENOVO/.cache\torch\hub\checkpoints\mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:05<00:00, 2.51MB/s]
# Epoch 1/5, Loss: 402.1028, Accuracy: 72.45%
# Epoch 2/5, Loss: 203.0253, Accuracy: 86.64%
# Epoch 3/5, Loss: 90.6461, Accuracy: 94.27%
# Epoch 4/5, Loss: 43.4095, Accuracy: 97.36%
# Epoch 5/5, Loss: 27.4185, Accuracy: 98.54%
# Classification Report:
#                                   precision    recall  f1-score   support
#
#        collision_with_motorcycle       0.94      0.91      0.93       182
# collision_with_stationary_object       0.79      0.68      0.73       306
#             drifting_or_skidding       0.78      0.87      0.82       380
#               fire_or_explosions       0.87      0.54      0.67        24
#                head_on_collision       0.87      0.86      0.86       158
#                 negative_samples       1.00      1.00      1.00      2063
#                  objects_falling       0.96      0.80      0.87        59
#                      other_crash       0.56      0.73      0.63        89
#                   pedestrian_hit       0.82      0.75      0.78        12
#                   rear_collision       0.88      0.89      0.88       177
#                         rollover       0.73      0.77      0.75       273
#                   side_collision       0.93      0.85      0.89       267
#
#                         accuracy                           0.91      3990
#                        macro avg       0.84      0.80      0.82      3990
#                     weighted avg       0.91      0.91      0.91      3990
#
# ✅ Model saved as incident_classifier_pytorch.pth
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import torch
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image
import os
import time

# === 1) Load your class names ===
DATA_DIR = r"C:\Users\LENOVO\Desktop\extracted_frames"
class_names = sorted(os.listdir(DATA_DIR))
num_classes = len(class_names)
print(f"[INFO] {num_classes} classes: {class_names}")

# === 2) Build MobileNetV2 with correct output size ===
model = models.mobilenet_v2(weights=None)
model.classifier[1] = torch.nn.Linear(model.last_channel, num_classes)

# === 3) Load checkpoint but skip final layer if sizes mismatch ===
checkpoint = torch.load('incident_classifier_pytorch.pth', map_location='cpu')
model_dict = model.state_dict()
filtered = {k: v for k, v in checkpoint.items()
            if k in model_dict and not k.startswith('classifier.1.')}
model_dict.update(filtered)
model.load_state_dict(model_dict)
model.eval()
print("[INFO] Loaded pretrained weights (excluding classifier head)")

# === 4) Prepare transforms ===
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# === 5) Open video ===
video_path = r"C:\Users\LENOVO\Downloads\video1.mp4"
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise RuntimeError(f"Cannot open video: {video_path}")

# === 6) Alert parameters ===
THRESHOLD = 0.9
ACCIDENT_KEYWORDS = {"collision", "crash", "accident", "hit", "wreck"}
NON_INCIDENT = {"car", "road", "traffic", "lane", "drive"}

COOLDOWN = 10           # seconds between alerts
ALERT_DURATION = 2      # seconds to show banner
CONSECUTIVE_REQ = 3     # consecutive frames needed

incident = False
last_alert_time = 0
streak = 0

# === 7) Main loop ===
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # — a) Model inference —
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil = Image.fromarray(rgb)
    tensor = transform(pil).unsqueeze(0)
    with torch.no_grad():
        out = model(tensor)
        probs = torch.nn.functional.softmax(out, dim=1)[0]
        idx = torch.argmax(probs).item()
        conf = probs[idx].item()
        label = class_names[idx]

    # — b) Overlay prediction text —
    cv2.putText(frame, f"{label}: {conf:.2f}", (20, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,255), 2)

    # — c) Decide “accident frame” —
    is_acc = any(k in label.lower() for k in ACCIDENT_KEYWORDS)
    is_black = label.lower() in NON_INCIDENT

    if is_acc and conf > THRESHOLD and not is_black:
        streak += 1
    else:
        streak = 0

    now = time.time()
    # — d) Trigger alert only after N consecutive frames and cooldown —
    if streak >= CONSECUTIVE_REQ and (not incident or now - last_alert_time > COOLDOWN):
        incident = True
        last_alert_time = now
        print("[ALERT] Accident Detected!")

    # — e) Draw banner for ALERT_DURATION seconds —
    if incident and (now - last_alert_time) < ALERT_DURATION:
        cv2.rectangle(frame, (0,60), (frame.shape[1],140), (0,0,0), -1)
        cv2.putText(frame, "⚠️ ACCIDENT DETECTED ⚠️", (20,120),
                    cv2.FONT_HERSHEY_DUPLEX, 2, (0,0,255), 3)
    else:
        incident = False

    # — f) Display —
    cv2.imshow("Traffic Incident Detection", frame)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [INFO] 12 classes: ['collision_with_motorcycle', 'collision_with_stationary_object', 'drifting_or_skidding', 'fire_or_explosions', 'head_on_collision', 'negative_samples', 'objects_falling', 'other_crash', 'pedestrian_hit', 'rear_collision', 'rollover', 'side_collision']
# [INFO] Loaded pretrained weights (excluding classifier head)

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from deep_sort_realtime.deepsort_tracker import DeepSort

# Load YOLO model
model = YOLO("yolov8n.pt")

# Vehicle class IDs from COCO: car=2, motorcycle=3, bus=5, truck=7
vehicle_classes = [2, 3, 5, 7]
class_names = {2: 'Car', 3: 'Motorcycle', 5: 'Bus', 7: 'Truck'}

# Object tracker
tracker = DeepSort(max_age=30, n_init=3, max_iou_distance=0.7)

# Load full video
video_path = r"C:\\Users\\LENOVO\\Downloads\\1192116-hd_1920_1080_30fps.mp4"
cap = cv2.VideoCapture(video_path)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter('final_vehicle_analysis.mp4', cv2.VideoWriter_fourcc(*'mp4v'), int(fps), (width, height))

# Vehicle ID tracking
vehicle_ids = set()
track_id_to_class = {}

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO prediction
    results = model.predict(frame, conf=0.5, iou=0.5, save=False, verbose=False)
    boxes = results[0].boxes

    detections = []
    for box in boxes:
        cls_id = int(box.cls[0])
        if cls_id in vehicle_classes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            if conf < 0.5 or (x2 - x1) < 30 or (y2 - y1) < 30:
                continue
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls_id))

    # Update tracker
    tracks = tracker.update_tracks(detections, frame=frame)
    annotated_frame = frame.copy()
    current_ids = set()

    seen_boxes = []

    for track in tracks:
        if not track.is_confirmed() or track.det_class not in vehicle_classes:
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)

        # Skip overlapping boxes (reduce double labeling)
        for sx1, sy1, sx2, sy2 in seen_boxes:
            if (
                abs(x1 - sx1) < 20 and
                abs(y1 - sy1) < 20 and
                abs(x2 - sx2) < 20 and
                abs(y2 - sy2) < 20
            ):
                break
        else:
            seen_boxes.append((x1, y1, x2, y2))

            cls_id = track.det_class
            class_name = class_names.get(cls_id, 'Vehicle')

            current_ids.add(track_id)
            track_id_to_class[track_id] = class_name

            label = f"ID:{track_id} | {class_name}"
            cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
            cv2.putText(annotated_frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
            cv2.putText(annotated_frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    # Update unique vehicle IDs
    vehicle_ids.update(current_ids)

    # Display total count
    cv2.rectangle(annotated_frame, (0, 0), (450, 50), (0, 0, 0), -1)
    cv2.putText(annotated_frame, f"Total Unique Vehicles: {len(vehicle_ids)}", (10, 35),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Show and save frame
    cv2.imshow("Vehicle Detection and Classification", annotated_frame)
    out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
from ultralytics import YOLO
import cv2
import numpy as np
import easyocr
from deep_sort_realtime.deepsort_tracker import DeepSort

# Load YOLO model
model = YOLO("yolov8n.pt")

# Vehicle classes from COCO: car=2, motorcycle=3, bus=5, truck=7
vehicle_classes = [2, 3, 5, 7]

# Number plate OCR
plate_reader = easyocr.Reader(['en'], gpu=False)

# Object tracker
tracker = DeepSort(max_age=30)

# Video path
video_path = r"C:\Users\LENOVO\Downloads\video1.mp4"
cap = cv2.VideoCapture(video_path)

# Output video settings
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter('final_vehicle_analysis.mp4', cv2.VideoWriter_fourcc(*'mp4v'), int(fps), (width, height))

# Track previous positions for speed
prev_positions = {}
vehicle_ids = set()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLOv8 prediction
    results = model.predict(source=frame, conf=0.4, save=False, verbose=False)
    boxes = results[0].boxes

    detections = []
    for box in boxes:
        cls_id = int(box.cls[0])
        if cls_id in vehicle_classes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls_id))

    # Object tracking
    tracks = tracker.update_tracks(detections, frame=frame)
    annotated_frame = frame.copy()
    current_ids = set()

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2
        current_ids.add(track_id)

        # Speed estimation
        if track_id in prev_positions:
            px, py = prev_positions[track_id]
            distance = np.sqrt((cx - px)**2 + (cy - py)**2)
            speed = int(distance * fps / 10)
        else:
            speed = 0
        prev_positions[track_id] = (cx, cy)

        # Number plate detection (only for large bounding boxes)
        plate_text = "None"
        crop = frame[y1:y2, x1:x2]
        if crop.size != 0 and (x2 - x1) > 50 and (y2 - y1) > 50:  # Apply a size filter for better accuracy
            results_plate = plate_reader.readtext(crop)
            if results_plate:
                plate_text = results_plate[0][1]
                print(f"Plate detected: {plate_text}")  # Debugging: print detected plate text

        # Annotate vehicle info
        label = f"ID:{track_id} | Speed: {speed}px/s | Plate: {plate_text}"
        print(label)  # Debugging: print label for each tracked vehicle

        cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 255), 2)
        cv2.putText(annotated_frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        cv2.putText(annotated_frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    # Total vehicle summary
    cv2.rectangle(annotated_frame, (0, 0), (300, 50), (0, 0, 0), -1)
    cv2.putText(annotated_frame, f"Total Vehicles: {len(current_ids)}", (10, 35),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Display and save
    cv2.imshow("Vehicle Detection with Speed & Plate", annotated_frame)
    out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # Update vehicle_ids with current confirmed vehicle IDs
    vehicle_ids.update(current_ids)

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# ID:1 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# ID:1 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 2px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 2px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# ID:1 | Speed: 0px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# Plate detected: ZYL
# ID:1 | Speed: 2px/s | Plate: ZYL
# ID:1 | Speed: 2px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 2px/s | Plate: ZYL
# ID:2 | Speed: 0px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# ID:2 | Speed: 13px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 13px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 16px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 13px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 17px/s | Plate: None
# Plate detected: ZYL
# ID:1 | Speed: 0px/s | Plate: ZYL
# ID:2 | Speed: 22px/s | Plate: None
# Plate detected: TYL
# ID:1 | Speed: 2px/s | Plate: TYL
# ID:2 | Speed: 12px/s | Plate: None
# Plate detected: 7YL
# ID:1 | Speed: 0px/s | Plate: 7YL
# ID:2 | Speed: 17px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 12px/s | Plate: None
# ID:1 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 14px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 12px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 15px/s | Plate: None
# ID:1 | Speed: 3px/s | Plate: None
# ID:2 | Speed: 9px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 12px/s | Plate: None
# ID:1 | Speed: 4px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 9px/s | Plate: None
# ID:2 | Speed: 18px/s | Plate: None
# ID:1 | Speed: 7px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 7px/s | Plate: None
# ID:2 | Speed: 15px/s | Plate: None
# ID:1 | Speed: 4px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 3px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 9px/s | Plate: None
# ID:1 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 9px/s | Plate: None
# ID:1 | Speed: 9px/s | Plate: None
# ID:2 | Speed: 9px/s | Plate: None
# ID:1 | Speed: 6px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 24px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 9px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 5px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 10px/s | Plate: None
# ID:1 | Speed: 6px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 3px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 7px/s | Plate: None
# ID:2 | Speed: 6px/s | Plate: None
# ID:1 | Speed: 3px/s | Plate: None
# Plate detected: bv
# ID:2 | Speed: 4px/s | Plate: bv
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: DV
# ID:2 | Speed: 9px/s | Plate: DV
# ID:1 | Speed: 7px/s | Plate: None
# Plate detected: by
# ID:2 | Speed: 5px/s | Plate: by
# ID:1 | Speed: 3px/s | Plate: None
# Plate detected: bV
# ID:2 | Speed: 5px/s | Plate: bV
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 7px/s | Plate: None
# ID:1 | Speed: 6px/s | Plate: None
# ID:2 | Speed: 5px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 4px/s | Plate: None
# ID:1 | Speed: 7px/s | Plate: None
# ID:2 | Speed: 5px/s | Plate: None
# ID:1 | Speed: 3px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 5px/s | Plate: St
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 2px/s | Plate: St
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 5px/s | Plate: St
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 3px/s | Plate: St
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: pte
# ID:2 | Speed: 5px/s | Plate: pte
# ID:1 | Speed: 6px/s | Plate: None
# Plate detected: tc
# ID:2 | Speed: 2px/s | Plate: tc
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 3px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 4px/s | Plate: None
# ID:6 | Speed: 0px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: CC
# ID:2 | Speed: 3px/s | Plate: CC
# ID:6 | Speed: 37px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: Ito
# ID:2 | Speed: 2px/s | Plate: Ito
# ID:6 | Speed: 33px/s | Plate: None
# ID:1 | Speed: 6px/s | Plate: None
# Plate detected: ito
# ID:2 | Speed: 3px/s | Plate: ito
# ID:6 | Speed: 29px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: ta
# ID:2 | Speed: 3px/s | Plate: ta
# ID:6 | Speed: 33px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# Plate detected: CO
# ID:2 | Speed: 2px/s | Plate: CO
# ID:6 | Speed: 29px/s | Plate: None
# ID:1 | Speed: 5px/s | Plate: None
# ID:2 | Speed: 4px/s | Plate: None
# ID:6 | Speed: 30px/s | Plate: None
# ID:2 | Speed: 2px/s | Plate: None
# ID:6 | Speed: 30px/s | Plate: None
# Plate detected: to
# ID:7 | Speed: 0px/s | Plate: to
# ID:2 | Speed: 2px/s | Plate: None
# ID:6 | Speed: 32px/s | Plate: None
# ID:7 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 3px/s | Plate: None
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: K
# ID:7 | Speed: 298px/s | Plate: K
# Plate detected: to
# ID:2 | Speed: 2px/s | Plate: to
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: tock
# ID:7 | Speed: 96px/s | Plate: tock
# ID:2 | Speed: 31px/s | Plate: None
# ID:6 | Speed: 28px/s | Plate: None
# Plate detected: tock
# ID:7 | Speed: 316px/s | Plate: tock
# ID:2 | Speed: 3px/s | Plate: None
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: tOCK
# ID:7 | Speed: 172px/s | Plate: tOCK
# Plate detected: tc
# ID:2 | Speed: 21px/s | Plate: tc
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: toc
# ID:7 | Speed: 76px/s | Plate: toc
# Plate detected: todl
# ID:2 | Speed: 307px/s | Plate: todl
# ID:6 | Speed: 28px/s | Plate: None
# Plate detected: tod
# ID:7 | Speed: 79px/s | Plate: tod
# Plate detected: Sto
# ID:2 | Speed: 100px/s | Plate: Sto
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: to
# ID:7 | Speed: 79px/s | Plate: to
# Plate detected: Stoe
# ID:2 | Speed: 43px/s | Plate: Stoe
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: Sto
# ID:7 | Speed: 79px/s | Plate: Sto
# Plate detected: Sta
# ID:2 | Speed: 17px/s | Plate: Sta
# ID:6 | Speed: 26px/s | Plate: None
# Plate detected: td
# ID:7 | Speed: 79px/s | Plate: td
# Plate detected: Stoc
# ID:2 | Speed: 2px/s | Plate: Stoc
# ID:6 | Speed: 28px/s | Plate: None
# Plate detected: Inac
# ID:7 | Speed: 79px/s | Plate: Inac
# Plate detected: iSt b
# ID:2 | Speed: 33px/s | Plate: iSt b
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 31px/s | Plate: iSt
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 172px/s | Plate: iSt
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 76px/s | Plate: None
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 28px/s | Plate: iSt
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 9px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 14px/s | Plate: iSt
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 12px/s | Plate: None
# Plate detected: iSta
# ID:2 | Speed: 38px/s | Plate: iSta
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 12px/s | Plate: None
# Plate detected: iSi
# ID:2 | Speed: 5px/s | Plate: iSi
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 7px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 0px/s | Plate: iS
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 9px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 2px/s | Plate: iS
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 5px/s | Plate: None
# Plate detected: iSte
# ID:2 | Speed: 2px/s | Plate: iSte
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 4px/s | Plate: None
# Plate detected: Getty
# ID:2 | Speed: 3px/s | Plate: Getty
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 76px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Getty
# ID:2 | Speed: 4px/s | Plate: Getty
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Gett}
# ID:2 | Speed: 4px/s | Plate: Gett}
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Gett
# ID:2 | Speed: 4px/s | Plate: Gett
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: Gett
# ID:2 | Speed: 4px/s | Plate: Gett
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 76px/s | Plate: None
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Geti
# ID:2 | Speed: 4px/s | Plate: Geti
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 8px/s | Plate: None
# Plate detected: Geti
# ID:2 | Speed: 2px/s | Plate: Geti
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 6px/s | Plate: None
# Plate detected: Get
# ID:2 | Speed: 2px/s | Plate: Get
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Get
# ID:2 | Speed: 2px/s | Plate: Get
# ID:6 | Speed: 26px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ger
# ID:2 | Speed: 5px/s | Plate: Ger
# ID:6 | Speed: 28px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 21px/s | Plate: Ge
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 7px/s | Plate: Ge
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# ID:2 | Speed: 2px/s | Plate: None
# ID:7 | Speed: 76px/s | Plate: None
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# ID:2 | Speed: 3px/s | Plate: None
# ID:7 | Speed: 79px/s | Plate: None
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 4px/s | Plate: Ge
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 4px/s | Plate: Ge
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: Ger
# ID:2 | Speed: 2px/s | Plate: Ger
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 16px/s | Plate: Ge
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 5px/s | Plate: None
# Plate detected: Ge
# ID:2 | Speed: 4px/s | Plate: Ge
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: Ger
# ID:2 | Speed: 4px/s | Plate: Ger
# ID:8 | Speed: 28px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: Ger
# ID:2 | Speed: 2px/s | Plate: Ger
# ID:8 | Speed: 38px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: Ger
# ID:2 | Speed: 7px/s | Plate: Ger
# ID:8 | Speed: 4px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: Gei=
# ID:2 | Speed: 5px/s | Plate: Gei=
# ID:8 | Speed: 4px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: Geti
# ID:2 | Speed: 2px/s | Plate: Geti
# ID:8 | Speed: 55px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: by Geti
# ID:2 | Speed: 33px/s | Plate: by Geti
# ID:8 | Speed: 9px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: DI
# ID:2 | Speed: 16px/s | Plate: DI
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: Gett
# ID:2 | Speed: 5px/s | Plate: Gett
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: by Getti
# ID:2 | Speed: 2px/s | Plate: by Getti
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: by Gettt
# ID:2 | Speed: 31px/s | Plate: by Gettt
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: by Getly
# ID:2 | Speed: 26px/s | Plate: by Getly
# ID:8 | Speed: 4px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 2px/s | Plate: iS
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 7px/s | Plate: iS
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 4px/s | Plate: iS
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 28px/s | Plate: iS
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 23px/s | Plate: iS
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: iS
# ID:2 | Speed: 48px/s | Plate: iS
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 21px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iS1
# ID:2 | Speed: 7px/s | Plate: iS1
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 7px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 2px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 9px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSi
# ID:2 | Speed: 9px/s | Plate: iSi
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 9px/s | Plate: iSt
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 7px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSi
# ID:2 | Speed: 14px/s | Plate: iSi
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: iSi
# ID:2 | Speed: 11px/s | Plate: iSi
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iSte
# ID:2 | Speed: 7px/s | Plate: iSte
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSte
# ID:2 | Speed: 3px/s | Plate: iSte
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 3px/s | Plate: iSt
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 2px/s | Plate: iSt
# ID:8 | Speed: 2px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 2px/s | Plate: iSt
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 2px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 0px/s | Plate: iSt
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: iSt
# ID:2 | Speed: 4px/s | Plate: iSt
# ID:8 | Speed: 4px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 2px/s | Plate: St
# ID:8 | Speed: 0px/s | Plate: None
# ID:12 | Speed: 0px/s | Plate: None
# Plate detected: St
# ID:2 | Speed: 2px/s | Plate: St
# ID:8 | Speed: 3px/s | Plate: None
# ID:12 | Speed: 3px/s | Plate: None
# Plate detected: iSte
# ID:2 | Speed: 0px/s | Plate: iSte
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 2px/s | Plate: Stod
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 0px/s | Plate: Stod
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 4px/s | Plate: Stod
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 0px/s | Plate: Stod
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Sto
# ID:2 | Speed: 2px/s | Plate: Sto
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stoc
# ID:2 | Speed: 2px/s | Plate: Stoc
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stoa
# ID:2 | Speed: 0px/s | Plate: Stoa
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stac
# ID:2 | Speed: 3px/s | Plate: Stac
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stoc
# ID:2 | Speed: 0px/s | Plate: Stoc
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stdc
# ID:2 | Speed: 2px/s | Plate: Stdc
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stc
# ID:2 | Speed: 3px/s | Plate: Stc
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stde
# ID:2 | Speed: 0px/s | Plate: Stde
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stde
# ID:2 | Speed: 0px/s | Plate: Stde
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stae
# ID:2 | Speed: 2px/s | Plate: Stae
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stde
# ID:2 | Speed: 2px/s | Plate: Stde
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stde
# ID:2 | Speed: 2px/s | Plate: Stde
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stac
# ID:2 | Speed: 2px/s | Plate: Stac
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stac
# ID:2 | Speed: 2px/s | Plate: Stac
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stac
# ID:2 | Speed: 2px/s | Plate: Stac
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stac
# ID:2 | Speed: 2px/s | Plate: Stac
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Sto
# ID:2 | Speed: 3px/s | Plate: Sto
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: Sto
# ID:2 | Speed: 3px/s | Plate: Sto
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Sto
# ID:2 | Speed: 2px/s | Plate: Sto
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stoe
# ID:2 | Speed: 2px/s | Plate: Stoe
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stoc
# ID:2 | Speed: 3px/s | Plate: Stoc
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stoc
# ID:2 | Speed: 0px/s | Plate: Stoc
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: Sto
# ID:2 | Speed: 2px/s | Plate: Sto
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: C
# ID:2 | Speed: 2px/s | Plate: C
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stol
# ID:2 | Speed: 0px/s | Plate: Stol
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: age
# ID:2 | Speed: 0px/s | Plate: age
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stol
# ID:2 | Speed: 0px/s | Plate: Stol
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stoch
# ID:2 | Speed: 0px/s | Plate: Stoch
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: Stoc
# ID:2 | Speed: 0px/s | Plate: Stoc
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: ager
# ID:2 | Speed: 2px/s | Plate: ager
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: ager
# ID:2 | Speed: 2px/s | Plate: ager
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: age
# ID:2 | Speed: 0px/s | Plate: age
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: age
# ID:2 | Speed: 0px/s | Plate: age
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: age;
# ID:2 | Speed: 2px/s | Plate: age;
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: nge
# ID:2 | Speed: 2px/s | Plate: nge
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stotk
# ID:2 | Speed: 0px/s | Plate: Stotk
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stoek
# ID:2 | Speed: 0px/s | Plate: stoek
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stotk
# ID:2 | Speed: 0px/s | Plate: stotk
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stoti
# ID:2 | Speed: 2px/s | Plate: stoti
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stod
# ID:2 | Speed: 0px/s | Plate: stod
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stode
# ID:2 | Speed: 0px/s | Plate: stode
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 0px/s | Plate: Stod
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stod
# ID:2 | Speed: 2px/s | Plate: Stod
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stodk
# ID:2 | Speed: 2px/s | Plate: stodk
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stodk
# ID:2 | Speed: 0px/s | Plate: stodk
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 0px/s | Plate: stock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stocki
# ID:2 | Speed: 2px/s | Plate: stocki
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 0px/s | Plate: stock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 3px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: Stocki
# ID:2 | Speed: 3px/s | Plate: Stocki
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 3px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: ctock
# ID:2 | Speed: 2px/s | Plate: ctock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 5px/s | Plate: None
# Plate detected: ~tock
# ID:2 | Speed: 0px/s | Plate: ~tock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 0px/s | Plate: stock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 2px/s | Plate: stock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 2px/s | Plate: stock
# ID:8 | Speed: 3px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 2px/s | Plate: stock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 9px/s | Plate: stock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 5px/s | Plate: tock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 5px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 2px/s | Plate: stock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 3px/s | Plate: stock
# Plate detected: 30
# ID:8 | Speed: 2px/s | Plate: 30
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: sel
# ID:8 | Speed: 0px/s | Plate: sel
# Plate detected: tock
# ID:2 | Speed: 3px/s | Plate: tock
# Plate detected: blet
# ID:8 | Speed: 0px/s | Plate: blet
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: Ibtt
# ID:8 | Speed: 0px/s | Plate: Ibtt
# Plate detected: tock
# ID:2 | Speed: 4px/s | Plate: tock
# Plate detected: byeae
# ID:8 | Speed: 3px/s | Plate: byeae
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: stock
# ID:2 | Speed: 0px/s | Plate: stock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: [st
# ID:8 | Speed: 0px/s | Plate: [st
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: Int
# ID:8 | Speed: 0px/s | Plate: Int
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: Int
# ID:8 | Speed: 2px/s | Plate: Int
# Plate detected: iotock
# ID:14 | Speed: 0px/s | Plate: iotock
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: int
# ID:8 | Speed: 2px/s | Plate: int
# Plate detected: intock
# ID:14 | Speed: 2px/s | Plate: intock
# Plate detected: tock
# ID:2 | Speed: 14px/s | Plate: tock
# ID:8 | Speed: 2px/s | Plate: None
# ID:14 | Speed: 0px/s | Plate: None
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: by
# ID:8 | Speed: 0px/s | Plate: by
# ID:14 | Speed: 0px/s | Plate: None
# Plate detected: atock
# ID:2 | Speed: 35px/s | Plate: atock
# Plate detected: int
# ID:8 | Speed: 3px/s | Plate: int
# Plate detected: ietock
# ID:14 | Speed: 2px/s | Plate: ietock
# Plate detected: ietock
# ID:2 | Speed: 23px/s | Plate: ietock
# Plate detected: int
# ID:8 | Speed: 0px/s | Plate: int
# Plate detected: iatock
# ID:14 | Speed: 2px/s | Plate: iatock
# Plate detected: stock
# ID:2 | Speed: 45px/s | Plate: stock
# Plate detected: iat
# ID:8 | Speed: 3px/s | Plate: iat
# Plate detected: ictock
# ID:14 | Speed: 4px/s | Plate: ictock
# Plate detected: Stock
# ID:2 | Speed: 2px/s | Plate: Stock
# Plate detected: iate
# ID:8 | Speed: 0px/s | Plate: iate
# Plate detected: iatock
# ID:14 | Speed: 0px/s | Plate: iatock
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: i8t
# ID:8 | Speed: 3px/s | Plate: i8t
# Plate detected: iatock
# ID:14 | Speed: 2px/s | Plate: iatock
# Plate detected: atock
# ID:2 | Speed: 2px/s | Plate: atock
# Plate detected: ict
# ID:8 | Speed: 0px/s | Plate: ict
# Plate detected: ictock
# ID:14 | Speed: 2px/s | Plate: ictock
# Plate detected: #tock
# ID:2 | Speed: 2px/s | Plate: #tock
# Plate detected: S4;
# ID:8 | Speed: 2px/s | Plate: S4;
# Plate detected: iStock
# ID:14 | Speed: 3px/s | Plate: iStock
# Plate detected: atock
# ID:2 | Speed: 0px/s | Plate: atock
# Plate detected: 4t
# ID:8 | Speed: 0px/s | Plate: 4t
# Plate detected: ictock
# ID:14 | Speed: 5px/s | Plate: ictock
# Plate detected: Ty Images'
# ID:2 | Speed: 2px/s | Plate: Ty Images'
# Plate detected: by
# ID:8 | Speed: 4px/s | Plate: by
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: Sock
# ID:2 | Speed: 0px/s | Plate: Sock
# Plate detected: by
# ID:8 | Speed: 0px/s | Plate: by
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: Stock
# ID:2 | Speed: 2px/s | Plate: Stock
# Plate detected: by
# ID:8 | Speed: 0px/s | Plate: by
# Plate detected: iStock
# ID:14 | Speed: 3px/s | Plate: iStock
# Plate detected: ty Images
# ID:2 | Speed: 57px/s | Plate: ty Images
# Plate detected: iatc
# ID:8 | Speed: 3px/s | Plate: iatc
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: ety Images
# ID:2 | Speed: 0px/s | Plate: ety Images
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: Rock
# ID:2 | Speed: 0px/s | Plate: Rock
# ID:8 | Speed: 0px/s | Plate: None
# Plate detected: icock
# ID:14 | Speed: 0px/s | Plate: icock
# Plate detected: Rock
# ID:2 | Speed: 2px/s | Plate: Rock
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: tocl
# ID:2 | Speed: 2px/s | Plate: tocl
# ID:8 | Speed: 2px/s | Plate: None
# Plate detected: iStocke
# ID:14 | Speed: 0px/s | Plate: iStocke
# Plate detected: tocl
# ID:2 | Speed: 2px/s | Plate: tocl
# Plate detected: iS
# ID:8 | Speed: 5px/s | Plate: iS
# Plate detected: iSkocke
# ID:14 | Speed: 0px/s | Plate: iSkocke
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: iS
# ID:8 | Speed: 2px/s | Plate: iS
# Plate detected: iStocke
# ID:14 | Speed: 0px/s | Plate: iStocke
# Plate detected: tocl
# ID:2 | Speed: 2px/s | Plate: tocl
# Plate detected: iSk
# ID:8 | Speed: 0px/s | Plate: iSk
# Plate detected: iStocke
# ID:14 | Speed: 0px/s | Plate: iStocke
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 3px/s | Plate: tock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStocl
# ID:14 | Speed: 0px/s | Plate: iStocl
# Plate detected: tocke
# ID:2 | Speed: 2px/s | Plate: tocke
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: iSte
# ID:8 | Speed: 3px/s | Plate: iSte
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: iSte
# ID:8 | Speed: 0px/s | Plate: iSte
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 0px/s | Plate: tock
# Plate detected: iSte
# ID:8 | Speed: 0px/s | Plate: iSte
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 3px/s | Plate: iStock
# Plate detected: tock
# ID:2 | Speed: 2px/s | Plate: tock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 129px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 9px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 7px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iSttock
# ID:15 | Speed: 2px/s | Plate: iSttock
# Plate detected: iStock
# ID:2 | Speed: 9px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 7px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 7px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 9px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# ID:15 | Speed: 0px/s | Plate: None
# Plate detected: iStock
# ID:2 | Speed: 9px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# ID:15 | Speed: 2px/s | Plate: None
# Plate detected: iStock
# ID:2 | Speed: 59px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 16px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 4px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 2px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:14 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 2px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 0px/s | Plate: iStc
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 4px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock_
# ID:15 | Speed: 2px/s | Plate: iStock_
# Plate detected: iStock
# ID:2 | Speed: 2px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 2px/s | Plate: iStc
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 4px/s | Plate: iStock
# Plate detected: iSt
# ID:8 | Speed: 2px/s | Plate: iSt
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 2px/s | Plate: iStock
# Plate detected: iSt
# ID:8 | Speed: 4px/s | Plate: iSt
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:17 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 2px/s | Plate: iStock
# Plate detected: iStc
# ID:8 | Speed: 3px/s | Plate: iStc
# Plate detected: iStock
# ID:15 | Speed: 0px/s | Plate: iStock
# Plate detected: iStock
# ID:17 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:2 | Speed: 4px/s | Plate: iStock
# Plate detected: iSt
# ID:8 | Speed: 3px/s | Plate: iSt
# Plate detected: iStock
# ID:15 | Speed: 2px/s | Plate: iStock
# Plate detected: iStock
# ID:17 | Speed: 0px/s | Plate: iStock
# Plate detected: Lock
# ID:2 | Speed: 141px/s | Plate: Lock
# Plate detected: iSte
# ID:8 | Speed: 7px/s | Plate: iSte
# Plate detected: iStock
# ID:15 | Speed: 12px/s | Plate: iStock
# Plate detected: iStock
# ID:17 | Speed: 2px/s | Plate: iStock

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from deep_sort_realtime.deepsort_tracker import DeepSort

# Load YOLOv8 model (you can use yolov8s.pt or yolov8m.pt for better accuracy)
model = YOLO("yolov8n.pt")

# COCO vehicle classes: car=2, motorcycle=3, bus=5, truck=7
vehicle_classes = [2, 3, 5, 7]

# Deep SORT tracker
tracker = DeepSort(max_age=30)

# Input video
video_path = r"C:\Users\LENOVO\Downloads\BB_1f9021bd-fcce-4f81-b2ec-caa17b70227c.mov"
cap = cv2.VideoCapture(video_path)

# Output video writer setup
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
out = cv2.VideoWriter('traffic_flow_analysis.mp4', cv2.VideoWriter_fourcc(*'mp4v'), int(fps), (width, height))

# Previous positions to estimate speed
prev_positions = {}

def analyze_traffic_flow(vehicle_speeds):
    """
    Analyze traffic flow based on number of vehicles and their speeds.
    """
    vehicle_count = len(vehicle_speeds)
    avg_speed = sum(vehicle_speeds) / vehicle_count if vehicle_count > 0 else 0

    if vehicle_count < 5 and avg_speed > 30:
        flow_status = "Free Flow"
    elif vehicle_count < 10 and avg_speed > 15:
        flow_status = "Moderate"
    else:
        flow_status = "Congested"

    return vehicle_count, avg_speed, flow_status

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, conf=0.4, save=False, verbose=False)
    boxes = results[0].boxes

    detections = []
    for box in boxes:
        cls_id = int(box.cls[0])
        if cls_id in vehicle_classes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = float(box.conf[0])
            detections.append(([x1, y1, x2 - x1, y2 - y1], conf, cls_id))

    tracks = tracker.update_tracks(detections, frame=frame)
    annotated_frame = frame.copy()
    vehicle_speeds = []

    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()
        x1, y1, x2, y2 = map(int, ltrb)
        cx, cy = (x1 + x2) // 2, (y1 + y2) // 2

        # Speed estimation in px/sec
        if track_id in prev_positions:
            px, py = prev_positions[track_id]
            distance = np.sqrt((cx - px) ** 2 + (cy - py) ** 2)
            speed = int(distance * fps / 10)  # adjust for realistic units
        else:
            speed = 0

        prev_positions[track_id] = (cx, cy)
        vehicle_speeds.append(speed)

        # Draw vehicle box and speed
        label = f"ID:{track_id} | Speed:{speed}px/s"
        cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(annotated_frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 2)
        cv2.putText(annotated_frame, label, (x1, y1 - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    # Analyze traffic flow
    count, avg_speed, flow_status = analyze_traffic_flow(vehicle_speeds)

    # Annotate results
    summary = f"Count: {count} | Avg Speed: {int(avg_speed)} px/s | Flow: {flow_status}"
    cv2.rectangle(annotated_frame, (0, 0), (450, 40), (0, 0, 0), -1)
    cv2.putText(annotated_frame, summary, (10, 25),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    # Display and save
    cv2.imshow("Traffic Flow Analysis", annotated_frame)
    out.write(annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2
import torch
import torchvision.transforms as transforms
from torchvision import models
from PIL import Image
import os
import time

# === 1) Load class names ===
DATA_DIR = r"C:\Users\LENOVO\Desktop\extracted_frames"
class_names = sorted(os.listdir(DATA_DIR))
num_classes = len(class_names)
print(f"[INFO] Loaded classes ({num_classes}): {class_names}")

# === 2) Build MobileNetV2 ===
model = models.mobilenet_v2(weights=None)
model.classifier[1] = torch.nn.Linear(model.last_channel, num_classes)

# === 3) Load checkpoint (skip mismatched head) ===
checkpoint = torch.load("incident_classifier_pytorch.pth", map_location="cpu")
model_dict = model.state_dict()
pretrained = {
    k: v for k,v in checkpoint.items()
    if k in model_dict and not k.startswith("classifier.1.")
}
model_dict.update(pretrained)
model.load_state_dict(model_dict)
model.eval()

# === 4) Transforms ===
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# === 5) Open video ===
cap = cv2.VideoCapture(r"C:\Users\LENOVO\Downloads\video1.mp4")
if not cap.isOpened():
    raise RuntimeError("Cannot open video")

# === 6) Alert & severity helpers ===
threshold = 0.85
cooldown = 5
alert_duration = 2
incident = False
last_alert = 0

def classify_accident_severity(conf):
    if conf > 0.8:
        return "High"
    elif conf > 0.5:
        return "Medium"
    else:
        return "Low"

# === 7) Process frames ===
while True:
    ret, frame = cap.read()
    if not ret: break

    # a) Preprocess
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil = Image.fromarray(rgb)
    tensor = transform(pil).unsqueeze(0)

    # b) Inference
    with torch.no_grad():
        out = model(tensor)
        probs = torch.nn.functional.softmax(out, dim=1)[0]
        idx = torch.argmax(probs).item()
        conf = probs[idx].item()
        label = class_names[idx]

    # c) Derive severity from confidence
    severity = classify_accident_severity(conf)

    # d) Overlay prediction + severity
    text = f"{label.upper()} | Sev: {severity} | {conf:.2f}"
    cv2.putText(frame, text, (20, 40),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,255), 2)

    # e) Alert logic
    now = time.time()
    if conf > threshold and severity != "Low":
        if not incident or (now - last_alert) > cooldown:
            incident = True
            last_alert = now
            print("🚨 ALERT: Incident Detected")

    # f) Draw alert banner
    if incident and (now - last_alert) < alert_duration:
        cv2.rectangle(frame, (0,60), (frame.shape[1],140), (0,0,0), -1)
        cv2.putText(frame, f"⚠️ {severity} SEVERITY ⚠️",
                    (20,120), cv2.FONT_HERSHEY_DUPLEX, 2, (0,0,255),3)
    else:
        incident = False

    # g) Show
    cv2.imshow("Incident & Severity Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [INFO] Loaded classes (12): ['collision_with_motorcycle', 'collision_with_stationary_object', 'drifting_or_skidding', 'fire_or_explosions', 'head_on_collision', 'negative_samples', 'objects_falling', 'other_crash', 'pedestrian_hit', 'rear_collision', 'rollover', 'side_collision']

# %%
import cv2
import winsound
from ultralytics import YOLO

# Load a YOLOv8 model (you can replace this with a custom accident model if trained)
model = YOLO("yolov8n.pt")  # Replace with "accident_model.pt" if available

def play_sound_alert():
    frequency = 2500  # Hz
    duration = 2000   # ms
    winsound.Beep(frequency, duration)

def detect_accidents(video_path):
    cap = cv2.VideoCapture(video_path)
    
    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        return

    # Define accident-related classes (depends on your model's labels)
    accident_keywords = {"car", "person", "truck", "bus", "motorcycle"}  # Modify for a custom model

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Perform detection
        results = model(frame, conf=0.5, verbose=False)[0]

        # Get class names detected
        detected_classes = [model.names[int(cls)] for cls in results.boxes.cls]

        # Count how many accident-related objects are detected
        accident_related = [cls for cls in detected_classes if cls in accident_keywords]

        # Trigger alert if multiple accident-related objects are detected
        if len(set(accident_related)) >= 2:  # Adjust threshold for your use case
            print("🚨 Accident Detected! Playing alert...")
            play_sound_alert()
            annotated_frame = results.plot()
        else:
            annotated_frame = frame

        # Show the frame
        cv2.imshow("Accident Detection", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# Run detection on a sample video
video_path = r"C:\Users\LENOVO\Downloads\video1.mp4"
detect_accidents(video_path)
# Out:
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
# 🚨 Accident Detected! Playing alert...
